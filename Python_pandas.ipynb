# %% [markdown]
# <a href="https://colab.research.google.com/github/anshudahiya121/Python_1/blob/main/Python_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WAP to create a series for numerical

# %%
import pandas as pd
s=pd.Series([2,4,6,8,10])
print(s)
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
import pandas as pd
s=pd.Series(["abc","bcd","def"])
print(s)
# Out:
# 0    abc
# 1    bcd
# 2    def
# dtype: object

# %% [markdown]
# WAPto make a data of students amrks

# %%
import pandas as pd
marks=pd.Series([99,98,97,96,95],index=["Ram","Shyam","Mohan","Geeta","Seeta"])
print(marks)
# Out:
# Ram      99
# Shyam    98
# Mohan    97
# Geeta    96
# Seeta    95
# dtype: int64

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan","Geeta","Seeta"],"Age":[20,22,44,46,95]}
df=pd.DataFrame(data)
print(df)
# Out:
#     Name  Age
# 0    Ram   20
# 1  Shyam   22
# 2  Mohan   44
# 3  Geeta   46
# 4  Seeta   95

# %%
import pandas as pd
marks=pd.Series([99,98,97,96,95],index=["Ram","Shyam","Mohan","Geeta","Seeta"])
df=pd.DataFrame(marks,columns=["Marks"])
df["Age"]=[15,17,22,45,32]
df["Gemder"]=["Male","Male","Male","Female","Female"]
df["Salary"]=[10000,20000,30000,40000,50000]
df["Experience in years"]=[1,2,3,4,5]
print(df)
# Out:
#        Marks  Age  Gemder  Salary  Experience in years
# Ram       99   15    Male   10000                    1
# Shyam     98   17    Male   20000                    2
# Mohan     97   22    Male   30000                    3
# Geeta     96   45  Female   40000                    4
# Seeta     95   32  Female   50000                    5

# %% [markdown]
# comapny data of 7 products..their slaes,rating

# %%
import pandas as pd
products=pd.Series(["Phone","Laptop","Earbuds","Charger","ipad","smartwatch","smartglasses"],index=[1,2,3,4,5,6,7])
df=pd.DataFrame(products,columns=["Apple Products"])
df["Sales"]=[1000,2000,3000,4000,5000,6000,7000]
df["Rating"]=["A","B","A+","A++","C","B+","A+++"]
print(df)
# Out:
#   Apple Products  Sales Rating
# 1          Phone   1000      A
# 2         Laptop   2000      B
# 3        Earbuds   3000     A+
# 4        Charger   4000    A++
# 5           ipad   5000      C
# 6     smartwatch   6000     B+
# 7   smartglasses   7000   A+++

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan","Geeta","Seeta","Rahul"],"Age":[20,22,44,46,95,25]}
df=pd.DataFrame(data)
print(df.head(3))
print(df.tail(3))
# Out:
#     Name  Age
# 0    Ram   20
# 1  Shyam   22
# 2  Mohan   44
#     Name  Age
# 3  Geeta   46
# 4  Seeta   95
# 5  Rahul   25

# %%
import pandas as pd
products=pd.Series(["Phone","Laptop","Earbuds","Charger","ipad","smartwatch","smartglasses"],index=[1,2,3,4,5,6,7])
df=pd.DataFrame(products,columns=["Apple Products"])
df["Sales"]=[1000,2000,3000,4000,5000,6000,7000]
df["Rating"]=["A","B","A+","A++","C","B+","A+++"]
print(df.tail(4))
# Out:
#   Apple Products  Sales Rating
# 4        Charger   4000    A++
# 5           ipad   5000      C
# 6     smartwatch   6000     B+
# 7   smartglasses   7000   A+++

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan","Geeta","Seeta","Rahul"],"Age":[20,22,44,46,95,25]}
df=pd.DataFrame(data)
print(df.sort_values("Age"))
# Out:
#     Name  Age
# 0    Ram   20
# 1  Shyam   22
# 5  Rahul   25
# 2  Mohan   44
# 3  Geeta   46
# 4  Seeta   95

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan","Geeta","Seeta","Rahul"],"Age":[20,22,44,46,95,25]}
df=pd.DataFrame(data)
print(df.sort_values("Age",ascending=False))
# Out:
#     Name  Age
# 4  Seeta   95
# 3  Geeta   46
# 2  Mohan   44
# 5  Rahul   25
# 1  Shyam   22
# 0    Ram   20

# %% [markdown]
# sort by name

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan","Geeta","Seeta","Rahul"],"Age":[20,22,44,46,95,25]}
df=pd.DataFrame(data)
print(df.sort_values("Name"))
# Out:
#     Name  Age
# 3  Geeta   46
# 2  Mohan   44
# 5  Rahul   25
# 0    Ram   20
# 4  Seeta   95
# 1  Shyam   22

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan","Geeta","Seeta","Rahul"],"Age":[20,22,44,46,95,25]}
df=pd.DataFrame(data)
print(df.sort_values("Name",ascending=False))
# Out:
#     Name  Age
# 1  Shyam   22
# 4  Seeta   95
# 0    Ram   20
# 5  Rahul   25
# 2  Mohan   44
# 3  Geeta   46

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan","Geeta","Seeta","Rahul"],"Age":[20,22,44,46,95,25],"Marks":[88,99,77,66,87,98]}
df=pd.DataFrame(data)
print(df.drop("Age",axis=1))
# Out:
#     Name  Marks
# 0    Ram     88
# 1  Shyam     99
# 2  Mohan     77
# 3  Geeta     66
# 4  Seeta     87
# 5  Rahul     98

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan","Geeta","Seeta","Rahul"],"Age":[20,22,44,46,95,25],"Marks":[88,99,77,66,87,98]}
df=pd.DataFrame(data)
print(df.drop(2))
# Out:
#     Name  Age  Marks
# 0    Ram   20     88
# 1  Shyam   22     99
# 3  Geeta   46     66
# 4  Seeta   95     87
# 5  Rahul   25     98

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan","Geeta","Seeta","Rahul"],"Age":[20,22,44,46,95,25],"Marks":[88,99,77,66,87,98]}
df=pd.DataFrame(data)
print(df.drop(columns=["Age","Marks"]))
# Out:
#     Name
# 0    Ram
# 1  Shyam
# 2  Mohan
# 3  Geeta
# 4  Seeta
# 5  Rahul

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan","Geeta","Seeta","Rahul"],"Age":[20,22,44,46,95,25],"Marks":[88,99,77,66,87,98]}
df=pd.DataFrame(data)
print(df.drop([2,3,4]))
# Out:
#     Name  Age  Marks
# 0    Ram   20     88
# 1  Shyam   22     99
# 5  Rahul   25     98

# %% [markdown]
# WAP employee name 5names, experience, salary...name drop..exp drop

# %%
import pandas as pd
data={"Employee Name":["Ram","Shyam","Mohan","Geeta","Seeta"],"Salary":[200000,220000,4400000,4600000,950000],"EXP in years":[8,9,7,6,8]}
df=pd.DataFrame(data)
print(df.drop(columns=["Employee Name","EXP in years"]))
# Out:
#     Salary
# 0   200000
# 1   220000
# 2  4400000
# 3  4600000
# 4   950000

# %%
import pandas as pd
data={"Employee Name":["Ram","Shyam","Mohan","Geeta","Seeta"],"Salary":[200000,220000,4400000,4600000,950000],"EXP in years":[8,9,7,6,8]}
df=pd.DataFrame(data)
print(df.drop("Salary",axis=1))
# Out:
#   Employee Name  EXP in years
# 0           Ram             8
# 1         Shyam             9
# 2         Mohan             7
# 3         Geeta             6
# 4         Seeta             8

# %% [markdown]
# WAP using loc() to change the age of the person at 0 index

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan"],"Age":[20,22,44]}
df=pd.DataFrame(data)
df.loc[0,"Age"]=25
print(df)
# Out:
#     Name  Age
# 0    Ram   25
# 1  Shyam   22
# 2  Mohan   44

# %% [markdown]
# WAP to update an entire row

# %%
import pandas as pd
data={"Name":["Ram","Shyam","Mohan"],"Age":[20,22,44]}
df=pd.DataFrame(data)
df.loc[0]=["Rahul",35]
print(df)
# Out:
#     Name  Age
# 0  Rahul   35
# 1  Shyam   22
# 2  Mohan   44

# %% [markdown]
# Wap to make a dataset of students name ram, aman, rahul, dev and marks 85, 90, 75, 95 filter students marks >80

# %%
import pandas as pd
data={"Name":["Ram","Aman","Rahul","Dev"],"Marks":[85,90,75,95]}
df=pd.DataFrame(data)
filtered_df = df[df["Marks"] > 80]
print(filtered_df)
# Out:
#    Name  Marks
# 0   Ram     85
# 1  Aman     90
# 3   Dev     95

# %% [markdown]
# WAP to filter the age of person > 18

# %%
import pandas as pd
data={"Name":["Ram","Aman","Rahul","Dev"],"Age":[12,9,35,25]}
df=pd.DataFrame(data)
filtered_df = df[df["Age"] > 18]
print(filtered_df)
# Out:
#     Name  Age
# 2  Rahul   35
# 3    Dev   25

# %% [markdown]
# Names-Aman rahul priya simaran neha karan
# age 20,21,22,20,23,21
# marks 85,90,78,92,88,75
# dept cse,it, cse, ece, it, cse
# 1.whose marks >80
# 2.belong to cse dep
# 3.whose age>20 n mark >80
# 4.whose name start with a
# 5.bring first 3 row of dataframe
# 6.display name n marks column
# 7.display the student at index 4 using loc
# 8.change rahul marks to 95
# 9.sort the student by marks in ascending order

# %%
import pandas as pd
data={"Name":["Aman","rahul","priya","simran","neha","karan"],"Age":[20,21,22,20,23,21],"Marks":[85,90,78,92,88,75],"Dept":["cse","it","cse","ece","it","cse"]}
df=pd.DataFrame(data)
filtered_df=df[df["Marks"] > 80]
print(filtered_df)
# Out:
#      Name  Age  Marks Dept
# 0    Aman   20     85  cse
# 1   rahul   21     90   it
# 3  simran   20     92  ece
# 4    neha   23     88   it

# %%
import pandas as pd
data={"Name":["Aman","rahul","priya","simran","neha","karan"],"Age":[20,21,22,20,23,21],"Marks":[85,90,78,92,88,75],"Dept":["cse","it","cse","ece","it","cse"]}
df=pd.DataFrame(data)
print(df.drop([1,3,4]))
# Out:
#     Name  Age  Marks Dept
# 0   Aman   20     85  cse
# 2  priya   22     78  cse
# 5  karan   21     75  cse

# %%
import pandas as pd
data={"Name":["Aman","rahul","priya","simran","neha","karan"],"Age":[20,21,22,20,23,21],"Marks":[85,90,78,92,88,75],"Dept":["cse","it","cse","ece","it","cse"]}
df=pd.DataFrame(data)
filtered_df=df[(df["Marks"] > 80) & (df["Age"] > 20)]
print(filtered_df)
# Out:
#     Name  Age  Marks Dept
# 1  rahul   21     90   it
# 4   neha   23     88   it

# %%
import pandas as pd
data={"Name":["aman","rahul","priya","simran","neha","karan"],"Age":[20,21,22,20,23,21],"Marks":[85,90,78,92,88,75],"Dept":["cse","it","cse","ece","it","cse"]}
df=pd.DataFrame(data)
starts_with_a = df[df["Name"].str.startswith("a", na=False)]
print(starts_with_a)
# Out:
#    Name  Age  Marks Dept
# 0  aman   20     85  cse

# %%
import pandas as pd
data={"Name":["aman","rahul","priya","simran","neha","karan"],"Age":[20,21,22,20,23,21],"Marks":[85,90,78,92,88,75],"Dept":["cse","it","cse","ece","it","cse"]}
df=pd.DataFrame(data)
print(df.head(3))
# Out:
#     Name  Age  Marks Dept
# 0   aman   20     85  cse
# 1  rahul   21     90   it
# 2  priya   22     78  cse

# %%
import pandas as pd
data={"Name":["aman","rahul","priya","simran","neha","karan"],"Age":[20,21,22,20,23,21],"Marks":[85,90,78,92,88,75],"Dept":["cse","it","cse","ece","it","cse"]}
df=pd.DataFrame(data)
print(df.drop(columns=["Age","Dept"]))
# Out:
#      Name  Marks
# 0    aman     85
# 1   rahul     90
# 2   priya     78
# 3  simran     92
# 4    neha     88
# 5   karan     75

# %%
import pandas as pd
data={"Name":["aman","rahul","priya","simran","neha","karan"],"Age":[20,21,22,20,23,21],"Marks":[85,90,78,92,88,75],"Dept":["cse","it","cse","ece","it","cse"]}
df=pd.DataFrame(data)
print(df.loc[4])
# Out:
# Name     neha
# Age        23
# Marks      88
# Dept       it
# Name: 4, dtype: object

# %%
import pandas as pd
data={"Name":["aman","rahul","priya","simran","neha","karan"],"Age":[20,21,22,20,23,21],"Marks":[85,90,78,92,88,75],"Dept":["cse","it","cse","ece","it","cse"]}
df=pd.DataFrame(data)
df.loc[1,"Marks"]=95
print(df)
# Out:
#      Name  Age  Marks Dept
# 0    aman   20     85  cse
# 1   rahul   21     95   it
# 2   priya   22     78  cse
# 3  simran   20     92  ece
# 4    neha   23     88   it
# 5   karan   21     75  cse

# %%
import pandas as pd
data={"Name":["aman","rahul","priya","simran","neha","karan"],"Age":[20,21,22,20,23,21],"Marks":[85,90,78,92,88,75],"Dept":["cse","it","cse","ece","it","cse"]}
df=pd.DataFrame(data)
print(df.sort_values("Marks"))
# Out:
#      Name  Age  Marks Dept
# 5   karan   21     75  cse
# 2   priya   22     78  cse
# 0    aman   20     85  cse
# 4    neha   23     88   it
# 1   rahul   21     90   it
# 3  simran   20     92  ece
